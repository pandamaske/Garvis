# %% [markdown]
# <a href="https://colab.research.google.com/github/pandamaske/Garvis/blob/main/paris_is_burning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from huggingface_hub import  notebook_login
notebook_login()

# %% [markdown]
# HUNITE LOGO

# %%
from diffusers import StableDiffusionPipeline, DDIMScheduler
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the Stable Diffusion model
pipe = StableDiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-2-base")
pipe.to(device)
# Example Stable Diffusion prompt in Python

prompt = (
    "A modern, minimalistic logo for an HCM platform called ‘Hunite’ (Humans United Network Information Systems). "
    "The logo should feature the letters H, U, and I. Design the ‘H’ to represent two people shaking hands, symbolizing partnership and collaboration. "
    "The ‘U’ should form a smile connecting the bottoms of the ‘H’ bars, representing satisfaction and positivity. "
    "The ‘I’ should be placed subtly behind the ‘H’, symbolizing support and integration. The design should be sleek, simple, and professional, emphasizing unity and trust. "
    "Use the colors #ffffff (white), #3200e2 (blue), and #eb692b (orange) to create a clean and impactful design."
)

negative_prompt = (
    "complex designs, overly intricate details, clutter, "
    "using gradients, shadows, or any 3D effects."
)


# Example inference settings
num_inference_steps = 50
guidance_scale = 7.5  # often called 'CFG Scale' in some UIs


image = pipe(
   prompt=prompt,
     negative_prompt=negative_prompt,
     guidance_scale=guidance_scale,
    num_inference_steps=num_inference_steps
 ).images[0]

#Save or display your image
image.save("output.png")
#
print("Image generated and saved!")
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (167 > 77). Running this sequence through the model will result in indexing errors
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['h ’ bars , representing satisfaction and positivity . the ‘ i ’ should be placed subtly behind the ‘ h ’, symbolizing support and integration . the design should be sleek , simple , and professional , emphasizing unity and trust . use the colors # ffffff ( white ), # 3 2 0 0 e 2 ( blue ), and # eb 6 9 2 b ( orange ) to create a clean and impactful design .']
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-009552bc6f0e> in <cell line: 30>()
#      28
#      29
# ...

# %% [markdown]
# Vladimir Putin

# %%
from diffusers import StableDiffusionPipeline, DDIMScheduler
import torch

# !huggingface-cli login

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the Stable Diffusion model
pipe = StableDiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-2-base")
pipe.to(device)
# Example Stable Diffusion prompt in Python

prompt = (

    "A black-and-white photograph of Validimir putin and kim jung standing close together "
    "in a narrow hallway, seen through a fisheye or peephole lens. They both wear "
    "thick, minimalistic overcoats and hold beverages (one holds a bottle, the other a glass). "
    "The overhead light creates soft but dramatic shadows, and the camera angle exaggerates "
    "the circular framing around them. Capture a subtle sense of humor or satire in their poses "
    "and expressions, with a somewhat cinematic or surreal atmosphere."
)

# An optional negative prompt to help steer the output away from undesired results
negative_prompt = (
    "blurry, out of frame, ugly, disfigured, oversaturated colors, unrealistic lighting"
)positive_prompt = (
    "A modern, minimalistic logo for an HCM platform called ‘Hunite’ (Humans United Network Information Systems). "
    "The logo should feature the letters H, U, and I. Design the ‘H’ to represent two people shaking hands, symbolizing partnership and collaboration. "
    "The ‘U’ should form a smile connecting the bottoms of the ‘H’ bars, representing satisfaction and positivity. "
    "The ‘I’ should be placed subtly behind the ‘H’, symbolizing support and integration. The design should be sleek, simple, and professional, emphasizing unity and trust. "
    "Use the colors #ffffff (white), #3200e2 (blue), and #eb692b (orange) to create a clean and impactful design."
)

negative_prompt = (
    "Avoid complex designs, overly intricate details, clutter, and elements that do not convey partnership, collaboration, satisfaction, positivity, support, integration, unity, or trust. "
    "Do not use colors outside of #ffffff (white), #3200e2 (blue), and #eb692b (orange). Avoid using gradients, shadows, or any 3D effects."
)


# Example inference settings
num_inference_steps = 50
guidance_scale = 7.5  # often called 'CFG Scale' in some UIs


image = pipe(
   prompt=prompt,
     negative_prompt=negative_prompt,
     guidance_scale=guidance_scale,
    num_inference_steps=num_inference_steps
 ).images[0]

#Save or display your image
image.save("output.png")
#
print("Image generated and saved!")
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# ...

# %%
from diffusers import StableDiffusionPipeline, DDIMScheduler
import torch

# !huggingface-cli login

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the Stable Diffusion model
pipe = StableDiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-2-base")
pipe.to(device)
# Define a detailed prompt
prompt = (
    "a Jewish shinigami in the Style of the manga bleach by tite kubo"
)
# Configure the scheduler
scheduler = DDIMScheduler(
    beta_start=0.00085,
    beta_end=0.012,
    beta_schedule="scaled_linear"
)
# Generate the image
image = pipe(
    prompt,
    scheduler=scheduler,
    num_inference_steps=50,
    guidance_scale=7.5,
    torch_dtype=torch.float16
).images[0]
# Save the generated image
image.save("paris_ruins.png")
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# ...

# %% [markdown]
# **FLUX 1 PRO ULTRA**

# %%
import torch
from diffusers import FluxPipeline
# !huggingface-cli login

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the Stable Diffusion model

pipe = FluxPipeline.from_pretrained("black-forest-labs/FLUX.1-dev", torch_dtype=torch.bfloat16)
pipe.to(device)

prompt = "A cat holding a sign that says hello world"
image = pipe(
    prompt,
    height=1024,
    width=1024,
    guidance_scale=3.5,
    num_inference_steps=50,
    max_sequence_length=512,
    generator=torch.Generator("cpu").manual_seed(0)
).images[0]
image.save("flux-dev.png")
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# ...

# %%
from huggingface_hub import InferenceClient
client = InferenceClient("stabilityai/stable-diffusion-3.5-large", token="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")
# output is a PIL.Image object
image = client.text_to_image("slightly thick beautiful algerian woman,"
"doggy style on the bed fully naked, hairy vagina"
"big ass oiled up,"
"in a bed ultra realistic,"
"kodak porta pro 400, 35mm, f2.0,")

image.save("algerian.png")

# %% [markdown]
# # **Inference Client**

# %%
from huggingface_hub import InferenceClient
client = InferenceClient("stabilityai/stable-diffusion-3.5-large", token="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")
# output is a PIL.Image object
image = client.text_to_image("fully naked beautiful algerian woman")
image.save("cat.png")

# %%
from huggingface_hub import InferenceClient
client = InferenceClient("stabilityai/stable-diffusion-3.5-large", token="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")
# output is a PIL.Image object
image = client.text_to_image(

    "A ultra realistic black-and-white leica photograph of Validimir putin and kim jung standing close together in the style of Daria Kosinova"
    "in a narrow hallway, seen through a fisheye or peephole lens. They are both looking directly at the peephole. They both wear "
    "thick, minimalistic overcoats and hold beverages (one holds a bottle, the other a glass). "
    "The overhead light creates soft but dramatic shadows, and the camera angle exaggerates "
    "the circular framing around them. Capture a subtle sense of humor or satire in their poses "
    "and expressions, with a somewhat cinematic or surreal atmosphere."
)

image.save("putin.png")

# %%
from huggingface_hub import InferenceClient
client = InferenceClient("stabilityai/stable-diffusion-3.5-large", token="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")
# output is a PIL.Image object
image = client.text_to_image(

    "A jewish orthodox shinigami in the style of Tite Kubo's manga Bleach, standing in the GOTEI 13, using the power of the torah as a super power, fighting a palestinian Arrancar"
)

image.save("bleach.png")

# %% [markdown]
# # **pony APIs**

# %%
from huggingface_hub import InferenceClient
client = InferenceClient("John6666/pornworks-real-porn-v03-sdxl", token="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")
# output is a PIL.Image object

image = client.text_to_image("slightly overweight arab morrocan woman with curly hair and tanned skin, sligh cellulite, slight stretchmarks, full frontal"
"in a bed ultra realistic,  kodak porta pro 400, 35mm, f2.0, "
    "Ultra realistic Fully Naked curvy and thick Moroccan woman anatomy wearing nothing,"
    "she is exposing her clitoris to the viewer"
    "she has a big fat ass, big thighs"
     "she's laying on her back, on the bed, her legs are wide opened")

image.save("ponyXLmax.png")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 504 Server Error: Gateway Timeout for url: https://api-inference.huggingface.co/models/John6666/pornworks-real-porn-v03-sdxl
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-2-6fa61630d50f> in <cell line: 5>()
#       3 # output is a PIL.Image object
#       4
# ...

# %%
from huggingface_hub import InferenceClient
client = InferenceClient("John6666/pornworks-real-porn-v03-sdxl", token="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")
# output is a PIL.Image object

image = client.text_to_image("an naked algerian woman")

image.save("ponyXL.png")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 504 Server Error: Gateway Timeout for url: https://api-inference.huggingface.co/models/John6666/pornworks-real-porn-v03-sdxl
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-1-1a3ba194c980> in <cell line: 5>()
#       3 # output is a PIL.Image object
#       4
# ...

# %% [markdown]
# ## `**PWORKS**`

# %%
import requests
API_URL = "https://api-inference.huggingface.co/models/John6666/pornworks-real-porn-v03-sdxl"
headers = {"Authorization": "Bearer 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"}
def query(payload):
  response = requests.post(API_URL, headers=headers, json=payload)
  return response.content
image_bytes = query({
"inputs": "a woman and darkened pussy and a photo of a woman being fucked by a man and a man's penis is being inserted into a woman's vagina and dark labia minora and dark clitoral hood",
})
# You can access the image with PIL.Image for example
import io
from PIL import Image

image.save("pworks.png")
